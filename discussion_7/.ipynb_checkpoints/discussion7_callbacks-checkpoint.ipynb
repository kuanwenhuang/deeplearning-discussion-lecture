# %%
import h5py
import os,sys,pdb,time
import numpy as np
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
keras.backend.clear_session()  # For easy reset of Jupyter notebook

# %%
############################################################
# Data: Load a subset of MNIST data
# split in into train and test
############################################################
# Load hdf5 file in 'r' mode
f = h5py.File('mnist_testdata.hdf5', 'r') # small dataset, assume this our full data
print('keys of the dataset: ', list(f.keys())) # useful for seeing the data set name/key
data = f['xdata'][:]
labels = f['ydata'][:]
print(data.shape, data.dtype, labels.shape, labels.dtype)
data,labels = shuffle(data, labels)

# preprocess the data
data = data/255
print(data.shape, data.dtype)

# spliting training and testing samples
split=7000
x_train = data[:split, ...]
x_test = data[split:,...]
y_train = labels[:split,...]
y_test = labels[split:,...]
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# keys of the dataset:  ['xdata', 'ydata']
# (10000, 784) uint8 (10000, 10) float64
# (10000, 784) float64
# 7000 train samples
# 3000 test samples

# %%
############################################################
# Define a functional API model
# Layer 1:                  784 * 64
# Activation 1:             relu
# Layer 2:                  64 * 10
# Activation 2:             softmax
############################################################

inputs = keras.Input(shape=(784,))

# a layer instance is callable on a tensor, and returns a tensor
h0 = keras.layers.Dense(64, activation='relu')(inputs)
outputs = keras.layers.Dense(10, activation='softmax')(h0)

# This creates a model that includes
# the Input layer and three Dense layers
model = keras.Model(inputs=inputs, outputs=outputs)

############################################################
# Model printing
############################################################
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# this will produce a digram of the model -- requires pydot and graphviz installed (pip install pydot graphviz)
# may need to update graphviz package first (Mac: brew install graphviz/Linux: sudo apt-get install graphviz)
keras.utils.plot_model(model, to_file='model_1.png', show_shapes=True, show_layer_names=True)

# %%
############################################################
# Model compilation
# Must be called before starting training
############################################################
# For a multi-class classification problem
model.compile(optimizer='sgd',
              loss='categorical_crossentropy', # categorical_crossentropy expects label to be one-hot vector
              metrics=['accuracy'])            # while sparse_categorical_crossentropy handles true labels as integers

# %%
# Callback object
mcp = keras.callbacks.ModelCheckpoint(filepath="models/best_model_1.hdf5", verbose=2 , save_best_only=True)
# Fitting the model with training data
results = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[mcp])
# You can also save the last model
model.save("models/end_model_1.hdf5")
# Out:
# Train on 5600 samples, validate on 1400 samples
# Epoch 1/50
# 4608/5600 [=======================>......] - ETA: 0s - loss: 1.7784 - accuracy: 0.5197
# Epoch 00001: val_loss improved from inf to 1.19040, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 1s 104us/sample - loss: 1.6837 - accuracy: 0.5591 - val_loss: 1.1904 - val_accuracy: 0.7607
# Epoch 2/50
# 4960/5600 [=========================>....] - ETA: 0s - loss: 0.9429 - accuracy: 0.8056
# Epoch 00002: val_loss improved from 1.19040 to 0.77532, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.9277 - accuracy: 0.8064 - val_loss: 0.7753 - val_accuracy: 0.8271
# Epoch 3/50
# 5056/5600 [==========================>...] - ETA: 0s - loss: 0.6715 - accuracy: 0.8483
# Epoch 00003: val_loss improved from 0.77532 to 0.60952, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.6617 - accuracy: 0.8504 - val_loss: 0.6095 - val_accuracy: 0.8550
# Epoch 4/50
# 4992/5600 [=========================>....] - ETA: 0s - loss: 0.5567 - accuracy: 0.8616
# Epoch 00004: val_loss improved from 0.60952 to 0.52895, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.5448 - accuracy: 0.8654 - val_loss: 0.5289 - val_accuracy: 0.8664
# Epoch 5/50
# 5024/5600 [=========================>....] - ETA: 0s - loss: 0.4829 - accuracy: 0.8804
# Epoch 00005: val_loss improved from 0.52895 to 0.47677, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.4785 - accuracy: 0.8798 - val_loss: 0.4768 - val_accuracy: 0.8764
# Epoch 6/50
# 5152/5600 [==========================>...] - ETA: 0s - loss: 0.4348 - accuracy: 0.8833
# Epoch 00006: val_loss improved from 0.47677 to 0.43944, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.4357 - accuracy: 0.8841 - val_loss: 0.4394 - val_accuracy: 0.8829
# Epoch 7/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.4059 - accuracy: 0.8927
# Epoch 00007: val_loss improved from 0.43944 to 0.41613, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.4044 - accuracy: 0.8941 - val_loss: 0.4161 - val_accuracy: 0.8921
# Epoch 8/50
# 4992/5600 [=========================>....] - ETA: 0s - loss: 0.3805 - accuracy: 0.9026
# Epoch 00008: val_loss improved from 0.41613 to 0.39555, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.3804 - accuracy: 0.9025 - val_loss: 0.3955 - val_accuracy: 0.8943
# Epoch 9/50
# 4992/5600 [=========================>....] - ETA: 0s - loss: 0.3608 - accuracy: 0.9085
# Epoch 00009: val_loss improved from 0.39555 to 0.38045, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.3615 - accuracy: 0.9071 - val_loss: 0.3804 - val_accuracy: 0.8964
# Epoch 10/50
# 5120/5600 [==========================>...] - ETA: 0s - loss: 0.3461 - accuracy: 0.9094
# Epoch 00010: val_loss improved from 0.38045 to 0.36610, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.3457 - accuracy: 0.9112 - val_loss: 0.3661 - val_accuracy: 0.9043
# Epoch 11/50
# 4960/5600 [=========================>....] - ETA: 0s - loss: 0.3347 - accuracy: 0.9099
# Epoch 00011: val_loss improved from 0.36610 to 0.35682, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.3326 - accuracy: 0.9123 - val_loss: 0.3568 - val_accuracy: 0.9029
# Epoch 12/50
# 4896/5600 [=========================>....] - ETA: 0s - loss: 0.3185 - accuracy: 0.9161
# Epoch 00012: val_loss improved from 0.35682 to 0.34531, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.3207 - accuracy: 0.9155 - val_loss: 0.3453 - val_accuracy: 0.9064
# Epoch 13/50
# 5056/5600 [==========================>...] - ETA: 0s - loss: 0.3140 - accuracy: 0.9187
# Epoch 00013: val_loss improved from 0.34531 to 0.33944, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.3096 - accuracy: 0.9195 - val_loss: 0.3394 - val_accuracy: 0.9036
# Epoch 14/50
# 5024/5600 [=========================>....] - ETA: 0s - loss: 0.3005 - accuracy: 0.9214
# Epoch 00014: val_loss improved from 0.33944 to 0.33174, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.3008 - accuracy: 0.9212 - val_loss: 0.3317 - val_accuracy: 0.9129
# Epoch 15/50
# 5024/5600 [=========================>....] - ETA: 0s - loss: 0.2949 - accuracy: 0.9236
# Epoch 00015: val_loss improved from 0.33174 to 0.32602, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.2918 - accuracy: 0.9250 - val_loss: 0.3260 - val_accuracy: 0.9136
# Epoch 16/50
# 4992/5600 [=========================>....] - ETA: 0s - loss: 0.2818 - accuracy: 0.9245
# Epoch 00016: val_loss improved from 0.32602 to 0.32192, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.2850 - accuracy: 0.9246 - val_loss: 0.3219 - val_accuracy: 0.9143
# Epoch 17/50
# 5088/5600 [==========================>...] - ETA: 0s - loss: 0.2759 - accuracy: 0.9269
# Epoch 00017: val_loss improved from 0.32192 to 0.31359, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.2782 - accuracy: 0.9257 - val_loss: 0.3136 - val_accuracy: 0.9179
# Epoch 18/50
# 4992/5600 [=========================>....] - ETA: 0s - loss: 0.2672 - accuracy: 0.9293
# Epoch 00018: val_loss improved from 0.31359 to 0.30781, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.2712 - accuracy: 0.9286 - val_loss: 0.3078 - val_accuracy: 0.9186
# Epoch 19/50
# 4416/5600 [======================>.......] - ETA: 0s - loss: 0.2658 - accuracy: 0.9309
# Epoch 00019: val_loss improved from 0.30781 to 0.30726, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.2647 - accuracy: 0.9298 - val_loss: 0.3073 - val_accuracy: 0.9129
# Epoch 20/50
# 4928/5600 [=========================>....] - ETA: 0s - loss: 0.2642 - accuracy: 0.9288
# Epoch 00020: val_loss improved from 0.30726 to 0.30275, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.2590 - accuracy: 0.9304 - val_loss: 0.3028 - val_accuracy: 0.9164
# Epoch 21/50
# 5120/5600 [==========================>...] - ETA: 0s - loss: 0.2563 - accuracy: 0.9309
# Epoch 00021: val_loss improved from 0.30275 to 0.29783, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 75us/sample - loss: 0.2531 - accuracy: 0.9327 - val_loss: 0.2978 - val_accuracy: 0.9193
# Epoch 22/50
# 5152/5600 [==========================>...] - ETA: 0s - loss: 0.2486 - accuracy: 0.9356
# Epoch 00022: val_loss improved from 0.29783 to 0.29449, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 71us/sample - loss: 0.2486 - accuracy: 0.9354 - val_loss: 0.2945 - val_accuracy: 0.9207
# Epoch 23/50
# 5312/5600 [===========================>..] - ETA: 0s - loss: 0.2414 - accuracy: 0.9373
# Epoch 00023: val_loss improved from 0.29449 to 0.29129, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 62us/sample - loss: 0.2431 - accuracy: 0.9362 - val_loss: 0.2913 - val_accuracy: 0.9186
# Epoch 24/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.2346 - accuracy: 0.9385
# Epoch 00024: val_loss improved from 0.29129 to 0.28953, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 67us/sample - loss: 0.2386 - accuracy: 0.9377 - val_loss: 0.2895 - val_accuracy: 0.9186
# Epoch 25/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.2350 - accuracy: 0.9406
# Epoch 00025: val_loss improved from 0.28953 to 0.28668, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 66us/sample - loss: 0.2345 - accuracy: 0.9404 - val_loss: 0.2867 - val_accuracy: 0.9171
# Epoch 26/50
# 5024/5600 [=========================>....] - ETA: 0s - loss: 0.2252 - accuracy: 0.9427
# Epoch 00026: val_loss improved from 0.28668 to 0.28376, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 74us/sample - loss: 0.2301 - accuracy: 0.9405 - val_loss: 0.2838 - val_accuracy: 0.9193
# Epoch 27/50
# 5184/5600 [==========================>...] - ETA: 0s - loss: 0.2241 - accuracy: 0.9425
# Epoch 00027: val_loss improved from 0.28376 to 0.28104, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 64us/sample - loss: 0.2257 - accuracy: 0.9423 - val_loss: 0.2810 - val_accuracy: 0.9229
# Epoch 28/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 0.2242 - accuracy: 0.9417
# Epoch 00028: val_loss improved from 0.28104 to 0.27680, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 87us/sample - loss: 0.2218 - accuracy: 0.9423 - val_loss: 0.2768 - val_accuracy: 0.9221
# Epoch 29/50
# 4704/5600 [========================>.....] - ETA: 0s - loss: 0.2233 - accuracy: 0.9428
# Epoch 00029: val_loss improved from 0.27680 to 0.27536, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 1s 104us/sample - loss: 0.2178 - accuracy: 0.9446 - val_loss: 0.2754 - val_accuracy: 0.9207
# Epoch 30/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.2123 - accuracy: 0.9442
# Epoch 00030: val_loss improved from 0.27536 to 0.27217, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 1s 94us/sample - loss: 0.2142 - accuracy: 0.9450 - val_loss: 0.2722 - val_accuracy: 0.9214
# Epoch 31/50
# 4640/5600 [=======================>......] - ETA: 0s - loss: 0.2106 - accuracy: 0.9461
# Epoch 00031: val_loss improved from 0.27217 to 0.27155, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.2103 - accuracy: 0.9455 - val_loss: 0.2715 - val_accuracy: 0.9229
# Epoch 32/50
# 4640/5600 [=======================>......] - ETA: 0s - loss: 0.2097 - accuracy: 0.9453
# Epoch 00032: val_loss improved from 0.27155 to 0.27031, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.2071 - accuracy: 0.9459 - val_loss: 0.2703 - val_accuracy: 0.9207
# Epoch 33/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.2007 - accuracy: 0.9492
# Epoch 00033: val_loss improved from 0.27031 to 0.26644, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.2033 - accuracy: 0.9471 - val_loss: 0.2664 - val_accuracy: 0.9214
# Epoch 34/50
# 5568/5600 [============================>.] - ETA: 0s - loss: 0.2005 - accuracy: 0.9483
# Epoch 00034: val_loss improved from 0.26644 to 0.26611, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.2004 - accuracy: 0.9484 - val_loss: 0.2661 - val_accuracy: 0.9200
# Epoch 35/50
# 5280/5600 [===========================>..] - ETA: 0s - loss: 0.1928 - accuracy: 0.9504
# Epoch 00035: val_loss did not improve from 0.26611
# 5600/5600 [==============================] - 0s 64us/sample - loss: 0.1968 - accuracy: 0.9486 - val_loss: 0.2663 - val_accuracy: 0.9214
# Epoch 36/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9499
# Epoch 00036: val_loss improved from 0.26611 to 0.26202, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 1s 108us/sample - loss: 0.1939 - accuracy: 0.9498 - val_loss: 0.2620 - val_accuracy: 0.9200
# Epoch 37/50
# 4480/5600 [=======================>......] - ETA: 0s - loss: 0.1915 - accuracy: 0.9525
# Epoch 00037: val_loss did not improve from 0.26202
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1907 - accuracy: 0.9511 - val_loss: 0.2661 - val_accuracy: 0.9186
# Epoch 38/50
# 4896/5600 [=========================>....] - ETA: 0s - loss: 0.1848 - accuracy: 0.9514
# Epoch 00038: val_loss improved from 0.26202 to 0.25940, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.1878 - accuracy: 0.9509 - val_loss: 0.2594 - val_accuracy: 0.9214
# Epoch 39/50
# 4704/5600 [========================>.....] - ETA: 0s - loss: 0.1804 - accuracy: 0.9534
# Epoch 00039: val_loss improved from 0.25940 to 0.25791, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 1s 92us/sample - loss: 0.1855 - accuracy: 0.9507 - val_loss: 0.2579 - val_accuracy: 0.9221
# Epoch 40/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.1770 - accuracy: 0.9538
# Epoch 00040: val_loss improved from 0.25791 to 0.25740, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1821 - accuracy: 0.9518 - val_loss: 0.2574 - val_accuracy: 0.9207
# Epoch 41/50
# 5184/5600 [==========================>...] - ETA: 0s - loss: 0.1795 - accuracy: 0.9547
# Epoch 00041: val_loss improved from 0.25740 to 0.25511, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 80us/sample - loss: 0.1796 - accuracy: 0.9541 - val_loss: 0.2551 - val_accuracy: 0.9207
# Epoch 42/50
# 4672/5600 [========================>.....] - ETA: 0s - loss: 0.1737 - accuracy: 0.9544
# Epoch 00042: val_loss improved from 0.25511 to 0.25399, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1766 - accuracy: 0.9536 - val_loss: 0.2540 - val_accuracy: 0.9207
# Epoch 43/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 0.1745 - accuracy: 0.9549
# Epoch 00043: val_loss did not improve from 0.25399
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.1739 - accuracy: 0.9536 - val_loss: 0.2544 - val_accuracy: 0.9193
# Epoch 44/50
# 4960/5600 [=========================>....] - ETA: 0s - loss: 0.1712 - accuracy: 0.9552
# Epoch 00044: val_loss improved from 0.25399 to 0.25044, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.1714 - accuracy: 0.9554 - val_loss: 0.2504 - val_accuracy: 0.9236
# Epoch 45/50
# 5248/5600 [===========================>..] - ETA: 0s - loss: 0.1682 - accuracy: 0.9560
# Epoch 00045: val_loss improved from 0.25044 to 0.24936, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.1697 - accuracy: 0.9554 - val_loss: 0.2494 - val_accuracy: 0.9236
# Epoch 46/50
# 4608/5600 [=======================>......] - ETA: 0s - loss: 0.1691 - accuracy: 0.9544
# Epoch 00046: val_loss improved from 0.24936 to 0.24869, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1667 - accuracy: 0.9555 - val_loss: 0.2487 - val_accuracy: 0.9207
# Epoch 47/50
# 4576/5600 [=======================>......] - ETA: 0s - loss: 0.1649 - accuracy: 0.9576
# Epoch 00047: val_loss improved from 0.24869 to 0.24867, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.1644 - accuracy: 0.9570 - val_loss: 0.2487 - val_accuracy: 0.9200
# Epoch 48/50
# 5024/5600 [=========================>....] - ETA: 0s - loss: 0.1624 - accuracy: 0.9570
# Epoch 00048: val_loss improved from 0.24867 to 0.24842, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.1621 - accuracy: 0.9570 - val_loss: 0.2484 - val_accuracy: 0.9207
# Epoch 49/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.1605 - accuracy: 0.9573
# Epoch 00049: val_loss improved from 0.24842 to 0.24572, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1602 - accuracy: 0.9575 - val_loss: 0.2457 - val_accuracy: 0.9221
# Epoch 50/50
# 4896/5600 [=========================>....] - ETA: 0s - loss: 0.1565 - accuracy: 0.9579
# Epoch 00050: val_loss did not improve from 0.24572
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.1575 - accuracy: 0.9582 - val_loss: 0.2462 - val_accuracy: 0.9214
