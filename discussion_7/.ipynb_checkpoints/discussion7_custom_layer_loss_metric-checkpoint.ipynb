# %%
import h5py
import os,sys,pdb,time
import numpy as np
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
keras.backend.clear_session()  # For easy reset of Jupyter notebook

# %%
############################################################
# Data: Load a subset of MNIST data
# split in into train and test
############################################################
# Load hdf5 file in 'r' mode
f = h5py.File('mnist_testdata.hdf5', 'r') # small dataset, assume this our full data
print('keys of the dataset: ', list(f.keys())) # useful for seeing the data set name/key
data = f['xdata'][:]
labels = f['ydata'][:]
print(data.shape, data.dtype, labels.shape, labels.dtype)
data,labels = shuffle(data, labels)

# preprocess the data
data = data/255
print(data.shape, data.dtype)

# spliting training and testing samples
split=7000
x_train = data[:split, ...]
x_test = data[split:,...]
y_train = labels[:split,...]
y_test = labels[split:,...]
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# keys of the dataset:  ['xdata', 'ydata']
# (10000, 784) uint8 (10000, 10) float64
# (10000, 784) float64
# 7000 train samples
# 3000 test samples

# %%
############################################################
# Define a functional API model
# Layer 1:                  784 * 64
# Activation 1:             relu
# Layer 2:                  64 * 32
# Activation 1:             relu
# Layer 3:                  32 * 10
# Activation 2:             softmax
############################################################

inputs = keras.Input(shape=(784,))

# a layer instance is callable on a tensor, and returns a tensor
h0 = keras.layers.Dense(64, activation='relu')(inputs)
h1 = keras.layers.Dense(32, activation='relu')(h0)
outputs = keras.layers.Dense(10, activation='softmax')(h1)

# This creates a model that includes
# the Input layer and three Dense layers
model = keras.Model(inputs=inputs, outputs=outputs)

############################################################
# Model printing
############################################################
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# this will produce a digram of the model -- requires pydot and graphviz installed (pip install pydot graphviz)
# may need to update graphviz package first (Mac: brew install graphviz/Linux: sudo apt-get install graphviz)
keras.utils.plot_model(model, to_file='model_2.png', show_shapes=True, show_layer_names=True)

# %%
############################################################
# Model compilation
# Must be called before starting training
############################################################
# For a multi-class classification problem
model.compile(optimizer='sgd',
              loss='categorical_crossentropy', # categorical_crossentropy expects label to be one-hot vector
              metrics=['accuracy'])            # while sparse_categorical_crossentropy handles true labels as integers

# %%
# Callback object 1
mcp = keras.callbacks.ModelCheckpoint(filepath="models/best_model_2.hdf5", verbose=2 , save_best_only=True)

# Custom Callback
class AccuracyLogger(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        print('Creating a log directory and cleaning files at the beginning of training')
        os.system('mkdir -p logs')
        with open('logs/train_acc.txt', 'w') as f: 
            f.write('')
        with open('logs/val_acc.txt', 'w') as f: 
            f.write('')

    def on_epoch_end(self, epoch, logs={}):
        print('Inside callback: epoch = ', epoch, 'logs = ', logs)
        train_acc = logs['accuracy']
        val_acc = logs['val_accuracy']
        with open('logs/train_acc.txt', 'a') as f: # open in append mode 'a', will clear previous data if use 'w'  
            f.write('Epoch {}: {}\n'.format(epoch, train_acc))
        with open('logs/val_acc.txt', 'a') as f: # open in append mode 'a', will clear previous data if use 'w'  
            f.write('Epoch {}: {}\n'.format(epoch, val_acc))

# Custom Callback object 2        
al = AccuracyLogger()

        
# Fitting the model with data
results = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[mcp, al])
# You can also save the last model
model.save("models/end_model_2.hdf5")
# Out:
# Train on 5600 samples, validate on 1400 samples
# Creating a log directory and cleaning files at the beginning of training
# Epoch 1/50
# 5248/5600 [===========================>..] - ETA: 0s - loss: 2.0507 - accuracy: 0.3432
# Epoch 00001: val_loss improved from inf to 1.65522, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  0 logs =  {'loss': 2.0288725314821514, 'accuracy': 0.36142856, 'val_loss': 1.655217364174979, 'val_accuracy': 0.645}
# 5600/5600 [==============================] - 1s 114us/sample - loss: 2.0289 - accuracy: 0.3614 - val_loss: 1.6552 - val_accuracy: 0.6450
# Epoch 2/50
# 4544/5600 [=======================>......] - ETA: 0s - loss: 1.3106 - accuracy: 0.7082
# Epoch 00002: val_loss improved from 1.65522 to 0.91932, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  1 logs =  {'loss': 1.2469649815559387, 'accuracy': 0.7230357, 'val_loss': 0.9193157141549246, 'val_accuracy': 0.80142856}
# 5600/5600 [==============================] - 0s 60us/sample - loss: 1.2470 - accuracy: 0.7230 - val_loss: 0.9193 - val_accuracy: 0.8014
# Epoch 3/50
# 4416/5600 [======================>.......] - ETA: 0s - loss: 0.7844 - accuracy: 0.8084
# Epoch 00003: val_loss improved from 0.91932 to 0.64087, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  2 logs =  {'loss': 0.7724578792708261, 'accuracy': 0.80875, 'val_loss': 0.6408710292407445, 'val_accuracy': 0.8464286}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.7725 - accuracy: 0.8087 - val_loss: 0.6409 - val_accuracy: 0.8464
# Epoch 4/50
# 5536/5600 [============================>.] - ETA: 0s - loss: 0.5896 - accuracy: 0.8475
# Epoch 00004: val_loss improved from 0.64087 to 0.51602, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  3 logs =  {'loss': 0.5883638034548079, 'accuracy': 0.8478571, 'val_loss': 0.5160248626981463, 'val_accuracy': 0.87857145}
# 5600/5600 [==============================] - 0s 78us/sample - loss: 0.5884 - accuracy: 0.8479 - val_loss: 0.5160 - val_accuracy: 0.8786
# Epoch 5/50
# 4544/5600 [=======================>......] - ETA: 0s - loss: 0.4974 - accuracy: 0.8702
# Epoch 00005: val_loss improved from 0.51602 to 0.44930, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  4 logs =  {'loss': 0.49378868818283084, 'accuracy': 0.8725, 'val_loss': 0.449298107113157, 'val_accuracy': 0.89}
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.4938 - accuracy: 0.8725 - val_loss: 0.4493 - val_accuracy: 0.8900
# Epoch 6/50
# 4896/5600 [=========================>....] - ETA: 0s - loss: 0.4331 - accuracy: 0.8854
# Epoch 00006: val_loss improved from 0.44930 to 0.40482, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  5 logs =  {'loss': 0.43384484699794224, 'accuracy': 0.88535714, 'val_loss': 0.4048175282137735, 'val_accuracy': 0.89928573}
# 5600/5600 [==============================] - 0s 72us/sample - loss: 0.4338 - accuracy: 0.8854 - val_loss: 0.4048 - val_accuracy: 0.8993
# Epoch 7/50
# 5088/5600 [==========================>...] - ETA: 0s - loss: 0.3945 - accuracy: 0.8909
# Epoch 00007: val_loss improved from 0.40482 to 0.37437, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  6 logs =  {'loss': 0.3919711173432214, 'accuracy': 0.89125, 'val_loss': 0.37436770881925313, 'val_accuracy': 0.9014286}
# 5600/5600 [==============================] - 0s 73us/sample - loss: 0.3920 - accuracy: 0.8913 - val_loss: 0.3744 - val_accuracy: 0.9014
# Epoch 8/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.3628 - accuracy: 0.9026
# Epoch 00008: val_loss improved from 0.37437 to 0.34862, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  7 logs =  {'loss': 0.3616151920386723, 'accuracy': 0.9032143, 'val_loss': 0.3486242856298174, 'val_accuracy': 0.9071429}
# 5600/5600 [==============================] - 0s 69us/sample - loss: 0.3616 - accuracy: 0.9032 - val_loss: 0.3486 - val_accuracy: 0.9071
# Epoch 9/50
# 5440/5600 [============================>.] - ETA: 0s - loss: 0.3406 - accuracy: 0.9061
# Epoch 00009: val_loss improved from 0.34862 to 0.32989, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  8 logs =  {'loss': 0.3377098282745906, 'accuracy': 0.9067857, 'val_loss': 0.3298858459506716, 'val_accuracy': 0.91071427}
# 5600/5600 [==============================] - 0s 60us/sample - loss: 0.3377 - accuracy: 0.9068 - val_loss: 0.3299 - val_accuracy: 0.9107
# Epoch 10/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.3175 - accuracy: 0.9139
# Epoch 00010: val_loss improved from 0.32989 to 0.32674, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  9 logs =  {'loss': 0.3172955581971577, 'accuracy': 0.91392857, 'val_loss': 0.32674198372023444, 'val_accuracy': 0.9121429}
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.3173 - accuracy: 0.9139 - val_loss: 0.3267 - val_accuracy: 0.9121
# Epoch 11/50
# 4576/5600 [=======================>......] - ETA: 0s - loss: 0.3039 - accuracy: 0.9163
# Epoch 00011: val_loss improved from 0.32674 to 0.30908, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  10 logs =  {'loss': 0.30251789727381295, 'accuracy': 0.9175, 'val_loss': 0.30908318374838145, 'val_accuracy': 0.91642857}
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.3025 - accuracy: 0.9175 - val_loss: 0.3091 - val_accuracy: 0.9164
# Epoch 12/50
# 5376/5600 [===========================>..] - ETA: 0s - loss: 0.2840 - accuracy: 0.9230
# Epoch 00012: val_loss improved from 0.30908 to 0.30494, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  11 logs =  {'loss': 0.2874065881541797, 'accuracy': 0.9219643, 'val_loss': 0.30494003806795394, 'val_accuracy': 0.9121429}
# 5600/5600 [==============================] - 0s 60us/sample - loss: 0.2874 - accuracy: 0.9220 - val_loss: 0.3049 - val_accuracy: 0.9121
# Epoch 13/50
# 4512/5600 [=======================>......] - ETA: 0s - loss: 0.2755 - accuracy: 0.9227
# Epoch 00013: val_loss improved from 0.30494 to 0.30025, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  12 logs =  {'loss': 0.2760748883656093, 'accuracy': 0.9226786, 'val_loss': 0.30025107758385794, 'val_accuracy': 0.9135714}
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.2761 - accuracy: 0.9227 - val_loss: 0.3003 - val_accuracy: 0.9136
# Epoch 14/50
# 5408/5600 [===========================>..] - ETA: 0s - loss: 0.2646 - accuracy: 0.9273
# Epoch 00014: val_loss did not improve from 0.30025
# Inside callback: epoch =  13 logs =  {'loss': 0.26485394124473843, 'accuracy': 0.9275, 'val_loss': 0.30368811930928913, 'val_accuracy': 0.9114286}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.2649 - accuracy: 0.9275 - val_loss: 0.3037 - val_accuracy: 0.9114
# Epoch 15/50
# 5376/5600 [===========================>..] - ETA: 0s - loss: 0.2565 - accuracy: 0.9301
# Epoch 00015: val_loss improved from 0.30025 to 0.28757, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  14 logs =  {'loss': 0.25600235355751855, 'accuracy': 0.93, 'val_loss': 0.28757456285612926, 'val_accuracy': 0.91785717}
# 5600/5600 [==============================] - 1s 93us/sample - loss: 0.2560 - accuracy: 0.9300 - val_loss: 0.2876 - val_accuracy: 0.9179
# Epoch 16/50
# 5056/5600 [==========================>...] - ETA: 0s - loss: 0.2469 - accuracy: 0.9337
# Epoch 00016: val_loss improved from 0.28757 to 0.28402, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  15 logs =  {'loss': 0.24686190328427723, 'accuracy': 0.93303573, 'val_loss': 0.28402161572660717, 'val_accuracy': 0.9185714}
# 5600/5600 [==============================] - 1s 91us/sample - loss: 0.2469 - accuracy: 0.9330 - val_loss: 0.2840 - val_accuracy: 0.9186
# Epoch 17/50
# 4544/5600 [=======================>......] - ETA: 0s - loss: 0.2291 - accuracy: 0.9406
# Epoch 00017: val_loss improved from 0.28402 to 0.27737, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  16 logs =  {'loss': 0.2369567676952907, 'accuracy': 0.9358929, 'val_loss': 0.2773707296167101, 'val_accuracy': 0.92214286}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.2370 - accuracy: 0.9359 - val_loss: 0.2774 - val_accuracy: 0.9221
# Epoch 18/50
# 4672/5600 [========================>.....] - ETA: 0s - loss: 0.2315 - accuracy: 0.9362
# Epoch 00018: val_loss improved from 0.27737 to 0.27577, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  17 logs =  {'loss': 0.23059790726218904, 'accuracy': 0.93642855, 'val_loss': 0.275773189834186, 'val_accuracy': 0.92214286}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.2306 - accuracy: 0.9364 - val_loss: 0.2758 - val_accuracy: 0.9221
# Epoch 19/50
# 4640/5600 [=======================>......] - ETA: 0s - loss: 0.2146 - accuracy: 0.9427
# Epoch 00019: val_loss improved from 0.27577 to 0.26950, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  18 logs =  {'loss': 0.2242552888393402, 'accuracy': 0.9392857, 'val_loss': 0.2695049686091287, 'val_accuracy': 0.92285717}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.2243 - accuracy: 0.9393 - val_loss: 0.2695 - val_accuracy: 0.9229
# Epoch 20/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.2165 - accuracy: 0.9385
# Epoch 00020: val_loss improved from 0.26950 to 0.26469, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  19 logs =  {'loss': 0.21684758609959057, 'accuracy': 0.9376786, 'val_loss': 0.26468629930700577, 'val_accuracy': 0.92785716}
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.2168 - accuracy: 0.9377 - val_loss: 0.2647 - val_accuracy: 0.9279
# Epoch 21/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.2043 - accuracy: 0.9433
# Epoch 00021: val_loss improved from 0.26469 to 0.26134, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  20 logs =  {'loss': 0.20925715774297715, 'accuracy': 0.9430357, 'val_loss': 0.26134494032178607, 'val_accuracy': 0.92714286}
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.2093 - accuracy: 0.9430 - val_loss: 0.2613 - val_accuracy: 0.9271
# Epoch 22/50
# 4704/5600 [========================>.....] - ETA: 0s - loss: 0.2041 - accuracy: 0.9458
# Epoch 00022: val_loss did not improve from 0.26134
# Inside callback: epoch =  21 logs =  {'loss': 0.20455840962273733, 'accuracy': 0.9439286, 'val_loss': 0.2651797434261867, 'val_accuracy': 0.9192857}
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.2046 - accuracy: 0.9439 - val_loss: 0.2652 - val_accuracy: 0.9193
# Epoch 23/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.2015 - accuracy: 0.9441
# Epoch 00023: val_loss improved from 0.26134 to 0.25881, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  22 logs =  {'loss': 0.19777679924454009, 'accuracy': 0.9455357, 'val_loss': 0.2588052644899913, 'val_accuracy': 0.92214286}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1978 - accuracy: 0.9455 - val_loss: 0.2588 - val_accuracy: 0.9221
# Epoch 24/50
# 4608/5600 [=======================>......] - ETA: 0s - loss: 0.1907 - accuracy: 0.9473
# Epoch 00024: val_loss did not improve from 0.25881
# Inside callback: epoch =  23 logs =  {'loss': 0.19272220485976765, 'accuracy': 0.94714284, 'val_loss': 0.26010067952530724, 'val_accuracy': 0.9242857}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1927 - accuracy: 0.9471 - val_loss: 0.2601 - val_accuracy: 0.9243
# Epoch 25/50
# 4640/5600 [=======================>......] - ETA: 0s - loss: 0.1858 - accuracy: 0.9509
# Epoch 00025: val_loss improved from 0.25881 to 0.25776, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  24 logs =  {'loss': 0.18647425340754645, 'accuracy': 0.95035714, 'val_loss': 0.2577578332168715, 'val_accuracy': 0.9257143}
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.1865 - accuracy: 0.9504 - val_loss: 0.2578 - val_accuracy: 0.9257
# Epoch 26/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.1781 - accuracy: 0.9504
# Epoch 00026: val_loss improved from 0.25776 to 0.25205, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  25 logs =  {'loss': 0.18271020359226636, 'accuracy': 0.94875, 'val_loss': 0.2520455489839826, 'val_accuracy': 0.92785716}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1827 - accuracy: 0.9488 - val_loss: 0.2520 - val_accuracy: 0.9279
# Epoch 27/50
# 4480/5600 [=======================>......] - ETA: 0s - loss: 0.1737 - accuracy: 0.9549
# Epoch 00027: val_loss did not improve from 0.25205
# Inside callback: epoch =  26 logs =  {'loss': 0.17553665740149363, 'accuracy': 0.9532143, 'val_loss': 0.25815508484840394, 'val_accuracy': 0.9242857}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1755 - accuracy: 0.9532 - val_loss: 0.2582 - val_accuracy: 0.9243
# Epoch 28/50
# 4608/5600 [=======================>......] - ETA: 0s - loss: 0.1694 - accuracy: 0.9516
# Epoch 00028: val_loss improved from 0.25205 to 0.25145, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  27 logs =  {'loss': 0.17226324577416693, 'accuracy': 0.95178574, 'val_loss': 0.2514545071550778, 'val_accuracy': 0.9292857}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.1723 - accuracy: 0.9518 - val_loss: 0.2515 - val_accuracy: 0.9293
# Epoch 29/50
# 4928/5600 [=========================>....] - ETA: 0s - loss: 0.1686 - accuracy: 0.9543
# Epoch 00029: val_loss improved from 0.25145 to 0.24819, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  28 logs =  {'loss': 0.16764884388872556, 'accuracy': 0.9555357, 'val_loss': 0.24819010768617902, 'val_accuracy': 0.93}
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1676 - accuracy: 0.9555 - val_loss: 0.2482 - val_accuracy: 0.9300
# Epoch 30/50
# 5536/5600 [============================>.] - ETA: 0s - loss: 0.1636 - accuracy: 0.9534
# Epoch 00030: val_loss did not improve from 0.24819
# Inside callback: epoch =  29 logs =  {'loss': 0.16284576433045522, 'accuracy': 0.95357144, 'val_loss': 0.24837177110569816, 'val_accuracy': 0.9307143}
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.1628 - accuracy: 0.9536 - val_loss: 0.2484 - val_accuracy: 0.9307
# Epoch 31/50
# 4544/5600 [=======================>......] - ETA: 0s - loss: 0.1608 - accuracy: 0.9558
# Epoch 00031: val_loss improved from 0.24819 to 0.24678, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  30 logs =  {'loss': 0.1589264266192913, 'accuracy': 0.95660716, 'val_loss': 0.2467779216170311, 'val_accuracy': 0.9292857}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.1589 - accuracy: 0.9566 - val_loss: 0.2468 - val_accuracy: 0.9293
# Epoch 32/50
# 4672/5600 [========================>.....] - ETA: 0s - loss: 0.1546 - accuracy: 0.9585
# Epoch 00032: val_loss improved from 0.24678 to 0.24565, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  31 logs =  {'loss': 0.15348615597401347, 'accuracy': 0.95910716, 'val_loss': 0.24564834973641805, 'val_accuracy': 0.9292857}
# 5600/5600 [==============================] - 0s 57us/sample - loss: 0.1535 - accuracy: 0.9591 - val_loss: 0.2456 - val_accuracy: 0.9293
# Epoch 33/50
# 4704/5600 [========================>.....] - ETA: 0s - loss: 0.1473 - accuracy: 0.9622
# Epoch 00033: val_loss did not improve from 0.24565
# Inside callback: epoch =  32 logs =  {'loss': 0.1502686763022627, 'accuracy': 0.9605357, 'val_loss': 0.246406629213265, 'val_accuracy': 0.9292857}
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.1503 - accuracy: 0.9605 - val_loss: 0.2464 - val_accuracy: 0.9293
# Epoch 34/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.1474 - accuracy: 0.9617
# Epoch 00034: val_loss improved from 0.24565 to 0.24368, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  33 logs =  {'loss': 0.14604542673698492, 'accuracy': 0.9623214, 'val_loss': 0.2436756323490824, 'val_accuracy': 0.93}
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.1460 - accuracy: 0.9623 - val_loss: 0.2437 - val_accuracy: 0.9300
# Epoch 35/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.1383 - accuracy: 0.9648
# Epoch 00035: val_loss improved from 0.24368 to 0.24221, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  34 logs =  {'loss': 0.14214058038379465, 'accuracy': 0.9621429, 'val_loss': 0.24221258448702948, 'val_accuracy': 0.93285716}
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.1421 - accuracy: 0.9621 - val_loss: 0.2422 - val_accuracy: 0.9329
# Epoch 36/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.1351 - accuracy: 0.9625
# Epoch 00036: val_loss improved from 0.24221 to 0.23944, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  35 logs =  {'loss': 0.13959622226655483, 'accuracy': 0.96160716, 'val_loss': 0.23943731818880354, 'val_accuracy': 0.93142855}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1396 - accuracy: 0.9616 - val_loss: 0.2394 - val_accuracy: 0.9314
# Epoch 37/50
# 5248/5600 [===========================>..] - ETA: 0s - loss: 0.1370 - accuracy: 0.9634
# Epoch 00037: val_loss improved from 0.23944 to 0.23911, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  36 logs =  {'loss': 0.13496349052659104, 'accuracy': 0.96410716, 'val_loss': 0.2391085482920919, 'val_accuracy': 0.9307143}
# 5600/5600 [==============================] - 0s 65us/sample - loss: 0.1350 - accuracy: 0.9641 - val_loss: 0.2391 - val_accuracy: 0.9307
# Epoch 38/50
# 5344/5600 [===========================>..] - ETA: 0s - loss: 0.1315 - accuracy: 0.9641
# Epoch 00038: val_loss did not improve from 0.23911
# Inside callback: epoch =  37 logs =  {'loss': 0.1316029178883348, 'accuracy': 0.96375, 'val_loss': 0.24197376417262215, 'val_accuracy': 0.93}
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.1316 - accuracy: 0.9638 - val_loss: 0.2420 - val_accuracy: 0.9300
# Epoch 39/50
# 4704/5600 [========================>.....] - ETA: 0s - loss: 0.1280 - accuracy: 0.9662
# Epoch 00039: val_loss did not improve from 0.23911
# Inside callback: epoch =  38 logs =  {'loss': 0.12807444990745612, 'accuracy': 0.96589285, 'val_loss': 0.24106785116451127, 'val_accuracy': 0.9307143}
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1281 - accuracy: 0.9659 - val_loss: 0.2411 - val_accuracy: 0.9307
# Epoch 40/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.1260 - accuracy: 0.9675
# Epoch 00040: val_loss improved from 0.23911 to 0.23882, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  39 logs =  {'loss': 0.12399253810090678, 'accuracy': 0.9678571, 'val_loss': 0.2388246836406844, 'val_accuracy': 0.92785716}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1240 - accuracy: 0.9679 - val_loss: 0.2388 - val_accuracy: 0.9279
# Epoch 41/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9673
# Epoch 00041: val_loss improved from 0.23882 to 0.23670, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  40 logs =  {'loss': 0.12089313774236611, 'accuracy': 0.9678571, 'val_loss': 0.23670136066419736, 'val_accuracy': 0.93285716}
# 5600/5600 [==============================] - 0s 62us/sample - loss: 0.1209 - accuracy: 0.9679 - val_loss: 0.2367 - val_accuracy: 0.9329
# Epoch 42/50
# 4928/5600 [=========================>....] - ETA: 0s - loss: 0.1193 - accuracy: 0.9679
# Epoch 00042: val_loss improved from 0.23670 to 0.23383, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  41 logs =  {'loss': 0.11800437606871128, 'accuracy': 0.96982145, 'val_loss': 0.23382640651294162, 'val_accuracy': 0.93285716}
# 5600/5600 [==============================] - 0s 87us/sample - loss: 0.1180 - accuracy: 0.9698 - val_loss: 0.2338 - val_accuracy: 0.9329
# Epoch 43/50
# 5056/5600 [==========================>...] - ETA: 0s - loss: 0.1147 - accuracy: 0.9705
# Epoch 00043: val_loss did not improve from 0.23383
# Inside callback: epoch =  42 logs =  {'loss': 0.11545161107821124, 'accuracy': 0.9689286, 'val_loss': 0.2369191201031208, 'val_accuracy': 0.93142855}
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.1155 - accuracy: 0.9689 - val_loss: 0.2369 - val_accuracy: 0.9314
# Epoch 44/50
# 4640/5600 [=======================>......] - ETA: 0s - loss: 0.1091 - accuracy: 0.9705
# Epoch 00044: val_loss improved from 0.23383 to 0.23351, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  43 logs =  {'loss': 0.11162254382989237, 'accuracy': 0.97017854, 'val_loss': 0.233509405787502, 'val_accuracy': 0.93214285}
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.1116 - accuracy: 0.9702 - val_loss: 0.2335 - val_accuracy: 0.9321
# Epoch 45/50
# 4512/5600 [=======================>......] - ETA: 0s - loss: 0.1100 - accuracy: 0.9725
# Epoch 00045: val_loss did not improve from 0.23351
# Inside callback: epoch =  44 logs =  {'loss': 0.10848917224577495, 'accuracy': 0.97339284, 'val_loss': 0.23432347376431736, 'val_accuracy': 0.935}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1085 - accuracy: 0.9734 - val_loss: 0.2343 - val_accuracy: 0.9350
# Epoch 46/50
# 4608/5600 [=======================>......] - ETA: 0s - loss: 0.1076 - accuracy: 0.9729
# Epoch 00046: val_loss did not improve from 0.23351
# Inside callback: epoch =  45 logs =  {'loss': 0.10621501732085432, 'accuracy': 0.97267854, 'val_loss': 0.23830663229737964, 'val_accuracy': 0.93285716}
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.1062 - accuracy: 0.9727 - val_loss: 0.2383 - val_accuracy: 0.9329
# Epoch 47/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.1019 - accuracy: 0.9745
# Epoch 00047: val_loss improved from 0.23351 to 0.23133, saving model to models/best_model_2.hdf5
# Inside callback: epoch =  46 logs =  {'loss': 0.10358887740543911, 'accuracy': 0.9735714, 'val_loss': 0.23132778295448847, 'val_accuracy': 0.9357143}
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1036 - accuracy: 0.9736 - val_loss: 0.2313 - val_accuracy: 0.9357
# Epoch 48/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.0987 - accuracy: 0.9760
# Epoch 00048: val_loss did not improve from 0.23133
# Inside callback: epoch =  47 logs =  {'loss': 0.10058669591588633, 'accuracy': 0.9742857, 'val_loss': 0.23492127799562046, 'val_accuracy': 0.93357146}
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1006 - accuracy: 0.9743 - val_loss: 0.2349 - val_accuracy: 0.9336
# Epoch 49/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.0987 - accuracy: 0.9745
# Epoch 00049: val_loss did not improve from 0.23133
# Inside callback: epoch =  48 logs =  {'loss': 0.09802948260945933, 'accuracy': 0.97482145, 'val_loss': 0.23183808980243548, 'val_accuracy': 0.935}
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.0980 - accuracy: 0.9748 - val_loss: 0.2318 - val_accuracy: 0.9350
# Epoch 50/50
# 4416/5600 [======================>.......] - ETA: 0s - loss: 0.0929 - accuracy: 0.9776
# Epoch 00050: val_loss did not improve from 0.23133
# Inside callback: epoch =  49 logs =  {'loss': 0.09488399470491068, 'accuracy': 0.9771429, 'val_loss': 0.2314255108152117, 'val_accuracy': 0.9357143}
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.0949 - accuracy: 0.9771 - val_loss: 0.2314 - val_accuracy: 0.9357
