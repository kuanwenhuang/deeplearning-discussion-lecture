# %%
import h5py
import os,sys,pdb,time
import numpy as np
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
keras.backend.clear_session()  # For easy reset of Jupyter notebook

path = os.getcwd()

# %%
############################################################
# Data: Load a subset of MNIST data
# split in into train and test
############################################################
# Load hdf5 file in 'r' mode
f = h5py.File('mnist_testdata.hdf5', 'r') # small dataset, assume this our full data
print('keys of the dataset: ', list(f.keys())) # useful for seeing the data set name/key
data = f['xdata'][:]
labels = f['ydata'][:]
print(data.shape, data.dtype, labels.shape, labels.dtype)
data,labels = shuffle(data, labels)

# preprocess the data
data = data/255
print(data.shape, data.dtype)

# spliting training and testing samples
split=7000
x_train = data[:split, ...]
x_test = data[split:,...]
y_train = labels[:split,...]
y_test = labels[split:,...]
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# keys of the dataset:  ['xdata', 'ydata']
# (10000, 784) uint8 (10000, 10) float64
# (10000, 784) float64
# 7000 train samples
# 3000 test samples

# %%
############################################################
# Define a functional API model
# Layer 1:                  784 * 64
# Activation 1:             relu
# Layer 2:                  64 * 32
# Activation 2:             relu
# Layer 3:                  32 * 10
# Activation 2:             softmax
############################################################

inputs = keras.Input(shape=(784,))

# a layer instance is callable on a tensor, and returns a tensor
h0 = keras.layers.Dense(64, activation='relu')(inputs)
outputs = keras.layers.Dense(10, activation='softmax')(h0)

# This creates a model that includes
# the Input layer and three Dense layers
model = keras.Model(inputs=inputs, outputs=outputs)

############################################################
# Model printing
############################################################
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# this will produce a digram of the model -- requires pydot and graphviz installed (pip install pydot graphviz)
# may need to update graphviz package first (Mac: brew install graphviz/Linux: sudo apt-get install graphviz)
keras.utils.plot_model(model, to_file='model_1.png', show_shapes=True, show_layer_names=True)

# %%
############################################################
# Model compilation
# Must be called before starting training
############################################################
# For a multi-class classification problem
model.compile(optimizer='sgd',
              loss='categorical_crossentropy', # categorical_crossentropy expects label to be one-hot vector
              metrics=['accuracy'])            # while sparse_categorical_crossentropy handles true labels as integers

# %%
# Callback object
mcp = keras.callbacks.ModelCheckpoint(filepath="models/best_model_1.hdf5", verbose=2 , save_best_only=True)
# Fitting the model with data
results = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[mcp])
# You can also save the last model
model.save("models/end_model_1.hdf5")
# Out:
# Train on 5600 samples, validate on 1400 samples
# Epoch 1/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 1.7553 - accuracy: 0.5256
# Epoch 00001: val_loss improved from inf to 1.20780, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 1s 105us/sample - loss: 1.6808 - accuracy: 0.5571 - val_loss: 1.2078 - val_accuracy: 0.7379
# Epoch 2/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.9683 - accuracy: 0.7918
# Epoch 00002: val_loss improved from 1.20780 to 0.80176, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.9455 - accuracy: 0.7959 - val_loss: 0.8018 - val_accuracy: 0.8143
# Epoch 3/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.6948 - accuracy: 0.8429
# Epoch 00003: val_loss improved from 0.80176 to 0.63550, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.6779 - accuracy: 0.8475 - val_loss: 0.6355 - val_accuracy: 0.8471
# Epoch 4/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 0.5627 - accuracy: 0.8637
# Epoch 00004: val_loss improved from 0.63550 to 0.54602, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.5544 - accuracy: 0.8670 - val_loss: 0.5460 - val_accuracy: 0.8593
# Epoch 5/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.4929 - accuracy: 0.8756
# Epoch 00005: val_loss improved from 0.54602 to 0.49223, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.4837 - accuracy: 0.8793 - val_loss: 0.4922 - val_accuracy: 0.8729
# Epoch 6/50
# 4640/5600 [=======================>......] - ETA: 0s - loss: 0.4342 - accuracy: 0.8927
# Epoch 00006: val_loss improved from 0.49223 to 0.45016, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.4370 - accuracy: 0.8909 - val_loss: 0.4502 - val_accuracy: 0.8836
# Epoch 7/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 0.4013 - accuracy: 0.8958
# Epoch 00007: val_loss improved from 0.45016 to 0.42405, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.4039 - accuracy: 0.8952 - val_loss: 0.4241 - val_accuracy: 0.8907
# Epoch 8/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.3834 - accuracy: 0.8985
# Epoch 00008: val_loss improved from 0.42405 to 0.40327, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.3786 - accuracy: 0.8996 - val_loss: 0.4033 - val_accuracy: 0.8900
# Epoch 9/50
# 4896/5600 [=========================>....] - ETA: 0s - loss: 0.3616 - accuracy: 0.9038
# Epoch 00009: val_loss improved from 0.40327 to 0.38916, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.3588 - accuracy: 0.9054 - val_loss: 0.3892 - val_accuracy: 0.8964
# Epoch 10/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.3473 - accuracy: 0.9073
# Epoch 00010: val_loss improved from 0.38916 to 0.37661, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.3416 - accuracy: 0.9095 - val_loss: 0.3766 - val_accuracy: 0.8957
# Epoch 11/50
# 4704/5600 [========================>.....] - ETA: 0s - loss: 0.3249 - accuracy: 0.9126
# Epoch 00011: val_loss improved from 0.37661 to 0.36173, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.3281 - accuracy: 0.9125 - val_loss: 0.3617 - val_accuracy: 0.8993
# Epoch 12/50
# 5408/5600 [===========================>..] - ETA: 0s - loss: 0.3158 - accuracy: 0.9161
# Epoch 00012: val_loss improved from 0.36173 to 0.35101, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.3154 - accuracy: 0.9159 - val_loss: 0.3510 - val_accuracy: 0.9050
# Epoch 13/50
# 4736/5600 [========================>.....] - ETA: 0s - loss: 0.3077 - accuracy: 0.9193
# Epoch 00013: val_loss improved from 0.35101 to 0.34512, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.3053 - accuracy: 0.9198 - val_loss: 0.3451 - val_accuracy: 0.9071
# Epoch 14/50
# 4480/5600 [=======================>......] - ETA: 0s - loss: 0.3024 - accuracy: 0.9196 ETA: 0s - loss: 0.3171 - accuracy: 0.
# Epoch 00014: val_loss improved from 0.34512 to 0.33575, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.2955 - accuracy: 0.9214 - val_loss: 0.3357 - val_accuracy: 0.9079
# Epoch 15/50
# 4896/5600 [=========================>....] - ETA: 0s - loss: 0.2874 - accuracy: 0.9265
# Epoch 00015: val_loss improved from 0.33575 to 0.33060, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.2867 - accuracy: 0.9246 - val_loss: 0.3306 - val_accuracy: 0.9071
# Epoch 16/50
# 4928/5600 [=========================>....] - ETA: 0s - loss: 0.2795 - accuracy: 0.9253
# Epoch 00016: val_loss improved from 0.33060 to 0.32468, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.2795 - accuracy: 0.9254 - val_loss: 0.3247 - val_accuracy: 0.9100
# Epoch 17/50
# 4960/5600 [=========================>....] - ETA: 0s - loss: 0.2709 - accuracy: 0.9270
# Epoch 00017: val_loss improved from 0.32468 to 0.31974, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.2721 - accuracy: 0.9266 - val_loss: 0.3197 - val_accuracy: 0.9121
# Epoch 18/50
# 4736/5600 [========================>.....] - ETA: 0s - loss: 0.2654 - accuracy: 0.9269
# Epoch 00018: val_loss improved from 0.31974 to 0.31647, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.2655 - accuracy: 0.9279 - val_loss: 0.3165 - val_accuracy: 0.9107
# Epoch 19/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.2607 - accuracy: 0.9285
# Epoch 00019: val_loss did not improve from 0.31647
# 5600/5600 [==============================] - 0s 68us/sample - loss: 0.2590 - accuracy: 0.9295 - val_loss: 0.3171 - val_accuracy: 0.9121
# Epoch 20/50
# 5120/5600 [==========================>...] - ETA: 0s - loss: 0.2561 - accuracy: 0.9293
# Epoch 00020: val_loss improved from 0.31647 to 0.30870, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 87us/sample - loss: 0.2536 - accuracy: 0.9296 - val_loss: 0.3087 - val_accuracy: 0.9150
# Epoch 21/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.2459 - accuracy: 0.9337
# Epoch 00021: val_loss improved from 0.30870 to 0.30585, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 69us/sample - loss: 0.2478 - accuracy: 0.9329 - val_loss: 0.3059 - val_accuracy: 0.9171
# Epoch 22/50
# 5472/5600 [============================>.] - ETA: 0s - loss: 0.2427 - accuracy: 0.9337
# Epoch 00022: val_loss improved from 0.30585 to 0.30032, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.2432 - accuracy: 0.9337 - val_loss: 0.3003 - val_accuracy: 0.9164
# Epoch 23/50
# 4672/5600 [========================>.....] - ETA: 0s - loss: 0.2358 - accuracy: 0.9358
# Epoch 00023: val_loss improved from 0.30032 to 0.29787, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.2373 - accuracy: 0.9355 - val_loss: 0.2979 - val_accuracy: 0.9157
# Epoch 24/50
# 4928/5600 [=========================>....] - ETA: 0s - loss: 0.2327 - accuracy: 0.9375
# Epoch 00024: val_loss improved from 0.29787 to 0.29731, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 61us/sample - loss: 0.2335 - accuracy: 0.9370 - val_loss: 0.2973 - val_accuracy: 0.9171
# Epoch 25/50
# 5472/5600 [============================>.] - ETA: 0s - loss: 0.2301 - accuracy: 0.9391
# Epoch 00025: val_loss improved from 0.29731 to 0.29518, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.2291 - accuracy: 0.9389 - val_loss: 0.2952 - val_accuracy: 0.9157
# Epoch 26/50
# 4736/5600 [========================>.....] - ETA: 0s - loss: 0.2270 - accuracy: 0.9388
# Epoch 00026: val_loss improved from 0.29518 to 0.29012, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 60us/sample - loss: 0.2246 - accuracy: 0.9395 - val_loss: 0.2901 - val_accuracy: 0.9164
# Epoch 27/50
# 4960/5600 [=========================>....] - ETA: 0s - loss: 0.2178 - accuracy: 0.9415
# Epoch 00027: val_loss improved from 0.29012 to 0.28921, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 62us/sample - loss: 0.2206 - accuracy: 0.9404 - val_loss: 0.2892 - val_accuracy: 0.9179
# Epoch 28/50
# 4960/5600 [=========================>....] - ETA: 0s - loss: 0.2192 - accuracy: 0.9409
# Epoch 00028: val_loss improved from 0.28921 to 0.28789, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.2170 - accuracy: 0.9414 - val_loss: 0.2879 - val_accuracy: 0.9164
# Epoch 29/50
# 5408/5600 [===========================>..] - ETA: 0s - loss: 0.2140 - accuracy: 0.9425
# Epoch 00029: val_loss improved from 0.28789 to 0.28740, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 63us/sample - loss: 0.2128 - accuracy: 0.9430 - val_loss: 0.2874 - val_accuracy: 0.9121
# Epoch 30/50
# 4576/5600 [=======================>......] - ETA: 0s - loss: 0.2024 - accuracy: 0.9454
# Epoch 00030: val_loss improved from 0.28740 to 0.28172, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.2090 - accuracy: 0.9439 - val_loss: 0.2817 - val_accuracy: 0.9150
# Epoch 31/50
# 5248/5600 [===========================>..] - ETA: 0s - loss: 0.2069 - accuracy: 0.9434
# Epoch 00031: val_loss did not improve from 0.28172
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.2050 - accuracy: 0.9439 - val_loss: 0.2825 - val_accuracy: 0.9179
# Epoch 32/50
# 5504/5600 [============================>.] - ETA: 0s - loss: 0.2022 - accuracy: 0.9437
# Epoch 00032: val_loss improved from 0.28172 to 0.27947, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 65us/sample - loss: 0.2021 - accuracy: 0.9441 - val_loss: 0.2795 - val_accuracy: 0.9171
# Epoch 33/50
# 5248/5600 [===========================>..] - ETA: 0s - loss: 0.2012 - accuracy: 0.9447
# Epoch 00033: val_loss improved from 0.27947 to 0.27676, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 83us/sample - loss: 0.1988 - accuracy: 0.9457 - val_loss: 0.2768 - val_accuracy: 0.9200
# Epoch 34/50
# 4576/5600 [=======================>......] - ETA: 0s - loss: 0.1975 - accuracy: 0.9469
# Epoch 00034: val_loss did not improve from 0.27676
# 5600/5600 [==============================] - 0s 55us/sample - loss: 0.1958 - accuracy: 0.9475 - val_loss: 0.2775 - val_accuracy: 0.9207
# Epoch 35/50
# 5312/5600 [===========================>..] - ETA: 0s - loss: 0.1922 - accuracy: 0.9477
# Epoch 00035: val_loss improved from 0.27676 to 0.27374, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 62us/sample - loss: 0.1927 - accuracy: 0.9475 - val_loss: 0.2737 - val_accuracy: 0.9193
# Epoch 36/50
# 5216/5600 [==========================>...] - ETA: 0s - loss: 0.1892 - accuracy: 0.9488
# Epoch 00036: val_loss did not improve from 0.27374
# 5600/5600 [==============================] - 0s 72us/sample - loss: 0.1890 - accuracy: 0.9489 - val_loss: 0.2743 - val_accuracy: 0.9207
# Epoch 37/50
# 5536/5600 [============================>.] - ETA: 0s - loss: 0.1872 - accuracy: 0.9503
# Epoch 00037: val_loss improved from 0.27374 to 0.27015, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 70us/sample - loss: 0.1867 - accuracy: 0.9505 - val_loss: 0.2702 - val_accuracy: 0.9193
# Epoch 38/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.1826 - accuracy: 0.9512
# Epoch 00038: val_loss did not improve from 0.27015
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.1837 - accuracy: 0.9504 - val_loss: 0.2724 - val_accuracy: 0.9221
# Epoch 39/50
# 5536/5600 [============================>.] - ETA: 0s - loss: 0.1810 - accuracy: 0.9498
# Epoch 00039: val_loss did not improve from 0.27015
# 5600/5600 [==============================] - 0s 58us/sample - loss: 0.1808 - accuracy: 0.9498 - val_loss: 0.2720 - val_accuracy: 0.9207
# Epoch 40/50
# 5312/5600 [===========================>..] - ETA: 0s - loss: 0.1781 - accuracy: 0.9535
# Epoch 00040: val_loss improved from 0.27015 to 0.26774, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 59us/sample - loss: 0.1781 - accuracy: 0.9534 - val_loss: 0.2677 - val_accuracy: 0.9179
# Epoch 41/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.1803 - accuracy: 0.9517
# Epoch 00041: val_loss did not improve from 0.26774
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1757 - accuracy: 0.9525 - val_loss: 0.2681 - val_accuracy: 0.9214
# Epoch 42/50
# 5184/5600 [==========================>...] - ETA: 0s - loss: 0.1726 - accuracy: 0.9552
# Epoch 00042: val_loss improved from 0.26774 to 0.26485, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 61us/sample - loss: 0.1728 - accuracy: 0.9550 - val_loss: 0.2649 - val_accuracy: 0.9179
# Epoch 43/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 0.1674 - accuracy: 0.9560
# Epoch 00043: val_loss did not improve from 0.26485
# 5600/5600 [==============================] - 0s 52us/sample - loss: 0.1702 - accuracy: 0.9559 - val_loss: 0.2665 - val_accuracy: 0.9250
# Epoch 44/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.1661 - accuracy: 0.9553
# Epoch 00044: val_loss improved from 0.26485 to 0.26364, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.1676 - accuracy: 0.9561 - val_loss: 0.2636 - val_accuracy: 0.9214
# Epoch 45/50
# 4768/5600 [========================>.....] - ETA: 0s - loss: 0.1671 - accuracy: 0.9568
# Epoch 00045: val_loss improved from 0.26364 to 0.26232, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1651 - accuracy: 0.9564 - val_loss: 0.2623 - val_accuracy: 0.9214
# Epoch 46/50
# 5472/5600 [============================>.] - ETA: 0s - loss: 0.1634 - accuracy: 0.9563
# Epoch 00046: val_loss did not improve from 0.26232
# 5600/5600 [==============================] - 0s 56us/sample - loss: 0.1624 - accuracy: 0.9568 - val_loss: 0.2631 - val_accuracy: 0.9193
# Epoch 47/50
# 4800/5600 [========================>.....] - ETA: 0s - loss: 0.1610 - accuracy: 0.9579
# Epoch 00047: val_loss improved from 0.26232 to 0.25956, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 54us/sample - loss: 0.1605 - accuracy: 0.9586 - val_loss: 0.2596 - val_accuracy: 0.9200
# Epoch 48/50
# 4864/5600 [=========================>....] - ETA: 0s - loss: 0.1601 - accuracy: 0.9587
# Epoch 00048: val_loss did not improve from 0.25956
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.1581 - accuracy: 0.9586 - val_loss: 0.2608 - val_accuracy: 0.9214
# Epoch 49/50
# 4992/5600 [=========================>....] - ETA: 0s - loss: 0.1569 - accuracy: 0.9611
# Epoch 00049: val_loss improved from 0.25956 to 0.25824, saving model to models/best_model_1.hdf5
# 5600/5600 [==============================] - 0s 53us/sample - loss: 0.1561 - accuracy: 0.9614 - val_loss: 0.2582 - val_accuracy: 0.9229
# Epoch 50/50
# 4832/5600 [========================>.....] - ETA: 0s - loss: 0.1527 - accuracy: 0.9609
# Epoch 00050: val_loss did not improve from 0.25824
# 5600/5600 [==============================] - 0s 51us/sample - loss: 0.1537 - accuracy: 0.9609 - val_loss: 0.2593 - val_accuracy: 0.9221
